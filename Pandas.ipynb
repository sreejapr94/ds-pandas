# %%
import pandas

# %%
cars= {"brand": "Ford",
  "electric": False,
  "year": 2020, 
  "colors": ["red", "white", "blue"],
  "seater": 5}
print(cars)
# Out:
# {'brand': 'Ford', 'electric': False, 'year': 2020, 'colors': ['red', 'white', 'blue'], 'seater': 5}

# %%
import pandas as pd
var = pd.DataFrame(cars)
print(var)
# Out:
#   brand  electric  year colors  seater
# 0  Ford     False  2020    red       5
# 1  Ford     False  2020  white       5
# 2  Ford     False  2020   blue       5

# %%
car1= {"brand": "Ford",
  "electric": False,
  "year": 2020, 
  "colors": "red",
  "seater": 5}

# %%
import pandas as pd
var = pd.DataFrame(car1,index=[1])
print(var)
# Out:
#   brand  electric  year colors  seater
# 1  Ford     False  2020    red       5

# %%
car2= {"brand": "BMW",
  "electric": False,
  "year": 2021, 
  "colors": "black",
  "seater": 5}
print(car2)
# Out:
# {'brand': 'BMW', 'electric': False, 'year': 2021, 'colors': 'black', 'seater': 5}

# %%
import pandas as pd
var = pd.DataFrame([car1,car2])
print(var)
# Out:
#   brand  electric  year colors  seater
# 0  Ford     False  2020    red       5
# 1   BMW     False  2021  black       5

# %%
pandas.__version__
# Out:
# '1.4.4'

# %%
import pandas as pd

List = [2,3,4,5,6,7]

var = pd.Series(List)

print(var)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
print(var[3])
# Out:
# 5

# %%
import pandas as pd

s = [2,3,4,5,6,7]

var = pd.Series(s,index = ["a", "b", "c","d","e","f"])

print(var)
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# f    7
# dtype: int64

# %%
print(var["d"])
# Out:
# 5

# %%
import pandas as pd

s = ["2","3","4","5","6","7"]

var = pd.Series(s,index = ["a", "b", "c","d","e","f"])

print(var)
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# f    7
# dtype: object

# %%
import pandas as pd
var = pd.DataFrame([car1,car2])
print(var)
# Out:
#   brand  electric  year colors  seater
# 0  Ford     False  2020    red       5
# 1   BMW     False  2021  black       5

# %%
import pandas as pd

cars = {"brand": "Ford", "electric": False, "year": 2020,"colors": ["red", "white", "blue"], "seater": 5}

var = pd.Series(cars, index = ["brand","year"])

print(var)
# Out:
# brand    Ford
# year     2020
# dtype: object

# %%
import pandas as pd
marks = {"Name" : ["Alex","John","Ben","Michelle","Ann","Steve"],
         "English" : [25,37,44,35,46,17],
          "Phy" : [45,32,21,24,33,47]}
marks_df = pd.DataFrame(marks)
print(marks_df)
# Out:
#        Name  English  Phy
# 0      Alex       25   45
# 1      John       37   32
# 2       Ben       44   21
# 3  Michelle       35   24
# 4       Ann       46   33
# 5     Steve       17   47

# %%
print(marks_df["Name"])
# Out:
# 0        Alex
# 1        John
# 2         Ben
# 3    Michelle
# 4         Ann
# 5       Steve
# Name: Name, dtype: object

# %%
print(marks_df.loc[[1]])

# %%
import pandas as pd
marks = {"Name" : ["Alex","John","Ben","Michelle","Ann","Steve"],
        "English" : [25,37,44,35,46,17],
          "Phy" : [45,32,21,24,33,47]}
stu_id = ["N123","N124","N234","N011","N023","N865"]
marks_df = pd.DataFrame(marks, index= stu_id)
print(marks_df)
# Out:
#           Name  English  Phy
# N123      Alex       25   45
# N124      John       37   32
# N234       Ben       44   21
# N011  Michelle       35   24
# N023       Ann       46   33
# N865     Steve       17   47

# %%
print(marks_df.loc[["N011","N124"]])
# Out:
#           Name  English  Phy
# N011  Michelle       35   24
# N124      John       37   32

# %% [markdown]
# # CSV FILES IN PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv("subway.csv")
print(df)
# Out:
#        index    name                                                url  \
# 0          0  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 1          1  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 2          2  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 3          3  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 4          4  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# ...      ...     ...                                                ...
# 25528  25528  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25529  25529  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25530  25530  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25531  25531  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 25532  25532  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#                                           street_address        city state  \
# ...

# %%
td_df= pd.read_excel("taxdata.xlsx")
print(td_df)
# Out:
#       Account Type  Account Group  Account Number       Category Location   \
# 0              VAT            500           50021           Asia     India
# 1              VAT            500           50021           Asia       UAE
# 2              VAT            500           50021           Asia     India
# 3              VAT            500           50021           Asia       UAE
# 4              VAT            500           50021           Asia     India
# ..             ...            ...             ...            ...       ...
# 160  Corporate Tax            600           60042  North America       USA
# 161  Corporate Tax            600           60042  North America       USA
# 162  Corporate Tax            600           60042  North America    Canada
# 163  Corporate Tax            600           60042  North America       USA
# 164  Corporate Tax            600           60042  North America       USA
#
#      Year  Collection       tax
# 0    2022       97841  17611.38
# ...

# %%
test_df = pd.read_csv("test.txt")
print(test_df)
# Out:
#               Reading data
# 0  Referencing in formulas
# 1               Name range
# 2        Logical Functions
# 3   Conditional Formatting
# 4     Advanced validations
# 5           Dynamic Tables
# 6    Sorting and Filtering

# %%
print(td_df.head(10))
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
# 5          VAT            500           50021     Asia       UAE  2019
# 6          VAT            500           50021     Asia       UAE  2022
# 7          VAT            500           50021     Asia     India  2021
# 8          VAT            500           50021     Asia     India  2022
# 9          VAT            500           50021     Asia       UAE  2018
#
#    Collection       tax
# 0       97841  17611.38
# 1       27652   4977.36
# 2       83770  15078.60
# 3       49229   8861.22
# 4       17539   3157.02
# 5       57948  10430.64
# ...

# %%
print(td_df.tail(5))
# Out:
#       Account Type  Account Group  Account Number       Category Location   \
# 160  Corporate Tax            600           60042  North America       USA
# 161  Corporate Tax            600           60042  North America       USA
# 162  Corporate Tax            600           60042  North America    Canada
# 163  Corporate Tax            600           60042  North America       USA
# 164  Corporate Tax            600           60042  North America       USA
#
#      Year  Collection       tax
# 160  2022       48461  12115.25
# 161  2020       24574   6143.50
# 162  2022       45276  11319.00
# 163  2021       23736   5934.00
# 164  2022       36999   9249.75

# %%
print(td_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account Type    165 non-null    object
#  1   Account Group   165 non-null    int64
#  2   Account Number  165 non-null    int64
#  3   Category        165 non-null    object
#  4   Location        165 non-null    object
#  5   Year            165 non-null    int64
#  6   Collection      165 non-null    int64
#  7   tax             165 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 10.4+ KB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25533 entries, 0 to 25532
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           25533 non-null  int64
#  1   name            25533 non-null  object
#  2   url             24017 non-null  object
#  3   street_address  25533 non-null  object
#  4   city            25533 non-null  object
#  5   state           25533 non-null  object
#  6   zip_code        25533 non-null  object
#  7   country         25533 non-null  object
#  8   phone_number_1  0 non-null      float64
#  9   phone_number_2  0 non-null      float64
#  10  fax_1           0 non-null      float64
#  11  fax_2           0 non-null      float64
#  12  email_1         0 non-null      float64
#  13  email_2         0 non-null      float64
#  14  website         0 non-null      float64
#  15  open_hours      25395 non-null  object
#  16  latitude        25533 non-null  float64
# ...

# %% [markdown]
# # Reading data in Pandas

# %%
##Reading headers

# %%
print(td_df.columns)
# Out:
# Index(['Account Type', 'Account Group', 'Account Number', 'Category',
#        'Location ', 'Year', 'Collection', 'tax'],
#       dtype='object')

# %%
## Reading each column

# %%
print(td_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account Type    165 non-null    object
#  1   Account Group   165 non-null    int64
#  2   Account Number  165 non-null    int64
#  3   Category        165 non-null    object
#  4   Location        165 non-null    object
#  5   Year            165 non-null    int64
#  6   Collection      165 non-null    int64
#  7   tax             165 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 10.4+ KB
# None

# %%
print(td_df["Category"])
# Out:
# 0               Asia
# 1               Asia
# 2               Asia
# 3               Asia
# 4               Asia
#            ...
# 160    North America
# 161    North America
# 162    North America
# 163    North America
# 164    North America
# Name: Category, Length: 165, dtype: object

# %%
print(td_df["Category"][0:5])
# Out:
# 0    Asia
# 1    Asia
# 2    Asia
# 3    Asia
# 4    Asia
# Name: Category, dtype: object

# %%
fields= ['Account Type', 'Category',"Location ", 'Year','Collection']
print(td_df[fields][0:5])

#OR

# print(td_df['Account Type', 'Category',"Location ", 'Year','Collection'][0:5])
# Out:
#   Account Type Category Location   Year  Collection
# 0          VAT     Asia     India  2022       97841
# 1          VAT     Asia       UAE  2018       27652
# 2          VAT     Asia     India  2019       83770
# 3          VAT     Asia       UAE  2022       49229
# 4          VAT     Asia     India  2018       17539

# %%
## Read Each Row

# %%
print(td_df.head(10))
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
# 5          VAT            500           50021     Asia       UAE  2019
# 6          VAT            500           50021     Asia       UAE  2022
# 7          VAT            500           50021     Asia     India  2021
# 8          VAT            500           50021     Asia     India  2022
# 9          VAT            500           50021     Asia       UAE  2018
#
#    Collection       tax
# 0       97841  17611.38
# 1       27652   4977.36
# 2       83770  15078.60
# 3       49229   8861.22
# 4       17539   3157.02
# 5       57948  10430.64
# ...

# %%
print(td_df.iloc[3:6])
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
# 5          VAT            500           50021     Asia       UAE  2019
#
#    Collection       tax
# 3       49229   8861.22
# 4       17539   3157.02
# 5       57948  10430.64

# %%
print(td_df.iloc[3,6])
# Out:
# 49229

# %%
print(df.iloc[3:5])
# Out:
#    index    name                                                url  \
# 3      3  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
# 4      4  Subway  http://order.subway.com/Stores/Redirect.aspx?s...
#
#                                    street_address        city state zip_code  \
# 3                      320 King Street, 1st Floor  Alexandria    VA    22314
# 4  5836 N. Kings Hwy, Suite A, Huntington Station  Alexandria    VA    22303
#
#   country  phone_number_1  phone_number_2  ...  email_2  website  \
# 3     USA             NaN             NaN  ...      NaN      NaN
# 4     USA             NaN             NaN  ...      NaN      NaN
#
#                                           open_hours  latitude  longitude  \
# 3  Sunday 9:00 AM - 8:00 PM, Monday 7:00 AM - 9:0...   38.8045   -77.0433
# 4  Sunday 9:00 AM - 9:00 PM, Monday 7:00 AM - 10:...   38.7903   -77.0769
#
#   facebook  twitter  instagram  pinterest  youtube
# ...

# %%
print(df.loc[1])

# %% [raw]
# print(df.iloc[1,4])

# %%
print(td_df.head(5))
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
#
#    Collection       tax
# 0       97841  17611.38
# 1       27652   4977.36
# 2       83770  15078.60
# 3       49229   8861.22
# 4       17539   3157.02

# %%
td_df.loc[td_df["Location "] == "India"]
# Out:
#       Account Type  Account Group  Account Number Category Location   Year  \
# 0              VAT            500           50021     Asia     India  2022
# 2              VAT            500           50021     Asia     India  2019
# 4              VAT            500           50021     Asia     India  2018
# 7              VAT            500           50021     Asia     India  2021
# 8              VAT            500           50021     Asia     India  2022
# ..             ...            ...             ...      ...       ...   ...
# 132  Corporate Tax            500           50022     Asia     India  2020
# 137  Corporate Tax            500           50022     Asia     India  2022
# 138  Corporate Tax            500           50022     Asia     India  2022
# 141  Corporate Tax            500           50022     Asia     India  2018
# 143  Corporate Tax            500           50022     Asia     India  2022
#
#      Collection       tax
# 0         97841  17611.38
# ...

# %% [markdown]
# ## Sorting/ Describe Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25533 entries, 0 to 25532
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           25533 non-null  int64
#  1   name            25533 non-null  object
#  2   url             24017 non-null  object
#  3   street_address  25533 non-null  object
#  4   city            25533 non-null  object
#  5   state           25533 non-null  object
#  6   zip_code        25533 non-null  object
#  7   country         25533 non-null  object
#  8   phone_number_1  0 non-null      float64
#  9   phone_number_2  0 non-null      float64
#  10  fax_1           0 non-null      float64
#  11  fax_2           0 non-null      float64
#  12  email_1         0 non-null      float64
#  13  email_2         0 non-null      float64
#  14  website         0 non-null      float64
#  15  open_hours      25395 non-null  object
#  16  latitude        25533 non-null  float64
# ...

# %%
td_df.describe()
# Out:
#        Account Group  Account Number         Year     Collection  \
# count     165.000000      165.000000   165.000000     165.000000
# mean      512.727273    51296.769697  2021.030303   60441.278788
# std        33.429278     3349.605737     1.407403   73592.945177
# min       500.000000    50021.000000  2018.000000   10915.000000
# 25%       500.000000    50021.000000  2020.000000   30700.000000
# 50%       500.000000    50022.000000  2022.000000   49229.000000
# 75%       500.000000    50022.000000  2022.000000   74968.000000
# max       600.000000    60042.000000  2022.000000  756000.000000
#
#                  tax
# count     165.000000
# mean    13073.692424
# std     16330.950800
# min      2167.200000
# 25%      6607.440000
# 50%     10743.800000
# 75%     15847.560000
# max    151200.000000

# %%
td_df.sort_values("Year") #ascending =False
# Out:
#       Account Type  Account Group  Account Number       Category  Location   \
# 50             VAT            500           50021           Asia      India
# 141  Corporate Tax            500           50022           Asia      India
# 18             VAT            500           50021           Asia        UAE
# 135  Corporate Tax            500           50022           Asia  Singapore
# 155  Corporate Tax            600           60042      Australia  Australia
# ..             ...            ...             ...            ...        ...
# 58             VAT            500           50021           Asia      India
# 57             VAT            500           50021           Asia     Kuwait
# 55             VAT            500           50021           Asia      India
# 75   Corporate Tax            500           50022           Asia      India
# 164  Corporate Tax            600           60042  North America        USA
#
#      Year  Collection       tax
# ...

# %%
Tax_In = td_df.loc[td_df["Location "] == "India"]
Tax_In.sort_values("Year")
# Out:
#       Account Type  Account Group  Account Number Category Location   Year  \
# 50             VAT            500           50021     Asia     India  2018
# 91   Corporate Tax            500           50022     Asia     India  2018
# 4              VAT            500           50021     Asia     India  2018
# 90   Corporate Tax            500           50022     Asia     India  2018
# 141  Corporate Tax            500           50022     Asia     India  2018
# ..             ...            ...             ...      ...       ...   ...
# 76   Corporate Tax            500           50022     Asia     India  2022
# 79   Corporate Tax            500           50022     Asia     India  2022
# 84   Corporate Tax            500           50022     Asia     India  2022
# 55             VAT            500           50021     Asia     India  2022
# 143  Corporate Tax            500           50022     Asia     India  2022
#
#      Collection       tax
# 50        67790  12202.20
# ...

# %%
Tax_In.sort_values("Year", ascending = False)
# Out:
#       Account Type  Account Group  Account Number Category Location   Year  \
# 0              VAT            500           50021     Asia     India  2022
# 73   Corporate Tax            500           50022     Asia     India  2022
# 76   Corporate Tax            500           50022     Asia     India  2022
# 78   Corporate Tax            500           50022     Asia     India  2022
# 84   Corporate Tax            500           50022     Asia     India  2022
# ..             ...            ...             ...      ...       ...   ...
# 91   Corporate Tax            500           50022     Asia     India  2018
# 50             VAT            500           50021     Asia     India  2018
# 4              VAT            500           50021     Asia     India  2018
# 141  Corporate Tax            500           50022     Asia     India  2018
# 34             VAT            500           50021     Asia     India  2018
#
#      Collection       tax
# 0         97841  17611.38
# ...

# %% [markdown]
# ### Making new data

# %%
import pandas as pd
td = pd.read_excel("taxdata.xlsx")
td['Actual_Revenue']=td['Collection']-td['tax']

# %%
td.head(5)
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
#
#    Collection       tax  Actual_Revenue
# 0       97841  17611.38        80229.62
# 1       27652   4977.36        22674.64
# 2       83770  15078.60        68691.40
# 3       49229   8861.22        40367.78
# 4       17539   3157.02        14381.98

# %%
td.drop(columns=['Account Type'])
td.head(5)
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
#
#    Collection       tax  Actual_Revenue
# 0       97841  17611.38        80229.62
# 1       27652   4977.36        22674.64
# 2       83770  15078.60        68691.40
# 3       49229   8861.22        40367.78
# 4       17539   3157.02        14381.98

# %%
import pandas as pd
td = pd.read_excel("taxdata.xlsx")
td['total']=td['Collection']+td['tax']
td['Actual_revenue']= td['Collection']- td['tax']
revenue = td[['Account Group','Account Number','Location ','total','Actual_revenue']]

# %%
revenue.head(5)
# Out:
#    Account Group  Account Number Location       total  Actual_revenue
# 0            500           50021     India  115452.38        80229.62
# 1            500           50021       UAE   32629.36        22674.64
# 2            500           50021     India   98848.60        68691.40
# 3            500           50021       UAE   58090.22        40367.78
# 4            500           50021     India   20696.02        14381.98

# %% [markdown]
# ## Save to a new Folder

# %%
revenue.to_csv("modified.csv")

# %%
mod = pd.read_csv("modified.csv")
mod.head(5)
# Out:
#    Unnamed: 0  Account Group  Account Number Location       total  \
# 0           0            500           50021     India  115452.38
# 1           1            500           50021       UAE   32629.36
# 2           2            500           50021     India   98848.60
# 3           3            500           50021       UAE   58090.22
# 4           4            500           50021     India   20696.02
#
#    Actual_revenue
# 0        80229.62
# 1        22674.64
# 2        68691.40
# 3        40367.78
# 4        14381.98

# %%
revenue.to_csv("modified.csv",index=False)
mod = pd.read_csv("modified.csv")
mod.head(5)
# Out:
#    Account Group  Account Number Location       total  Actual_revenue
# 0            500           50021     India  115452.38        80229.62
# 1            500           50021       UAE   32629.36        22674.64
# 2            500           50021     India   98848.60        68691.40
# 3            500           50021       UAE   58090.22        40367.78
# 4            500           50021     India   20696.02        14381.98

# %%
revenue.to_excel("modified.xlsx", index= False)
mod = pd.read_excel("modified.xlsx")
mod.head(5)
# Out:
#    Account Group  Account Number Location       total  Actual_revenue
# 0            500           50021     India  115452.38        80229.62
# 1            500           50021       UAE   32629.36        22674.64
# 2            500           50021     India   98848.60        68691.40
# 3            500           50021       UAE   58090.22        40367.78
# 4            500           50021     India   20696.02        14381.98

# %%
revenue.to_csv("modified.txt", index= False , sep ='\t')
mod = pd.read_csv("modified.csv")
mod.head(5)
# Out:
#    Account Group  Account Number Location       total  Actual_revenue
# 0            500           50021     India  115452.38        80229.62
# 1            500           50021       UAE   32629.36        22674.64
# 2            500           50021     India   98848.60        68691.40
# 3            500           50021       UAE   58090.22        40367.78
# 4            500           50021     India   20696.02        14381.98

# %% [markdown]
# ## Filter data

# %%
import pandas as pd
td = pd.read_excel("taxdata.xlsx")
td.head(10)
# Out:
#   Account Type  Account Group  Account Number Category Location   Year  \
# 0          VAT            500           50021     Asia     India  2022
# 1          VAT            500           50021     Asia       UAE  2018
# 2          VAT            500           50021     Asia     India  2019
# 3          VAT            500           50021     Asia       UAE  2022
# 4          VAT            500           50021     Asia     India  2018
# 5          VAT            500           50021     Asia       UAE  2019
# 6          VAT            500           50021     Asia       UAE  2022
# 7          VAT            500           50021     Asia     India  2021
# 8          VAT            500           50021     Asia     India  2022
# 9          VAT            500           50021     Asia       UAE  2018
#
#    Collection       tax
# 0       97841  17611.38
# 1       27652   4977.36
# 2       83770  15078.60
# 3       49229   8861.22
# 4       17539   3157.02
# 5       57948  10430.64
# ...

# %%
td.loc[(td["Category"]=="Asia")& (td["Year"]==2018)&(td["Account Number"]==50021)]
# Out:
#    Account Type  Account Group  Account Number Category Location   Year  \
# 1           VAT            500           50021     Asia       UAE  2018
# 4           VAT            500           50021     Asia     India  2018
# 9           VAT            500           50021     Asia       UAE  2018
# 18          VAT            500           50021     Asia       UAE  2018
# 34          VAT            500           50021     Asia     India  2018
# 50          VAT            500           50021     Asia     India  2018
# 62          VAT            500           50021     Asia       UAE  2018
#
#     Collection       tax      total  Actual_revenue
# 1        27652   4977.36   32629.36        22674.64
# 4        17539   3157.02   20696.02        14381.98
# 9        32673   5881.14   38554.14        26791.86
# 18       88563  15941.34  104504.34        72621.66
# 34       77880  14018.40   91898.40        63861.60
# 50       67790  12202.20   79992.20        55587.80
# ...

# %%
import pandas as pd
df =pd.read_csv("pokemon_data.txt")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ### Create a new column with the sum and average of the 6 fields  and create a seperate file having Name, type1 , type2 , sum and average

# %%
import pandas as pd
df =pd.read_csv("pokemon_data.csv")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df["Sum"]=df["HP"]+df["Attack"]+df["Defense"]+df["Sp. Atk"]
df["Average"]=(df["HP"]+df["Attack"])/2

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0       65     45           1      False  208     47.0
# 1       80     60           1      False  265     61.0
# 2      100     80           1      False  345     81.0
# 3      120     80           1      False  425     90.0
# 4       50     65           1      False  194     45.5

# %%
45+49+49
# Out:
# 143

# %%
new = df[['Name','Type 1','Type 2','Sum','Average']]

# %%
new.head(5)
# Out:
#                     Name Type 1  Type 2  Sum  Average
# 0              Bulbasaur  Grass  Poison   94     47.0
# 1                Ivysaur  Grass  Poison  122     61.0
# 2               Venusaur  Grass  Poison  162     81.0
# 3  VenusaurMega Venusaur  Grass  Poison  180     90.0
# 4             Charmander   Fire     NaN   91     45.5

# %%
df.to_csv("sum_ave_pd.csv", index = False)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0       65     45           1      False  208     47.0
# 1       80     60           1      False  265     61.0
# 2      100     80           1      False  345     81.0
# 3      120     80           1      False  425     90.0
# 4       50     65           1      False  194     45.5

# %%
df.to_csv("/Users/sreeja/Desktop/sum_ave_pd.csv", index=False)

# %% [markdown]
# ### Filter the data for type 1 = Bug and type 2 = Flying

# %%
df.loc[(df["Type 1"]=="Bug")]
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 15    12               Butterfree    Bug    Flying  60      45       50
# 16    13                   Weedle    Bug    Poison  40      35       30
# 17    14                   Kakuna    Bug    Poison  45      25       50
# 18    15                 Beedrill    Bug    Poison  65      90       40
# 19    15    BeedrillMega Beedrill    Bug    Poison  65     150       40
# 51    46                    Paras    Bug     Grass  35      70       55
# 52    47                 Parasect    Bug     Grass  60      95       80
# 53    48                  Venonat    Bug    Poison  60      55       50
# 54    49                 Venomoth    Bug    Poison  70      65       60
# 132  123                  Scyther    Bug    Flying  70     110       80
# 137  127        PinsirMega Pinsir    Bug    Flying  65     155      120
# 179  165                   Ledyba    Bug    Flying  40      20       30
# ...

# %%
newdata = df.loc[(df["Type 1"]=="Bug")&(df["Type 2"]=="Poison")&(df['HP'] > 40)]
newdata
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 17    14                 Kakuna    Bug  Poison  45      25       50       25
# 18    15               Beedrill    Bug  Poison  65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison  65     150       40       15
# 53    48                Venonat    Bug  Poison  60      55       50       40
# 54    49               Venomoth    Bug  Poison  70      65       60       90
# 182  168                Ariados    Bug  Poison  70      90       70       60
# 292  269                 Dustox    Bug  Poison  60      50       70       50
# 605  545              Scolipede    Bug  Poison  60     100       89       55
#
#      Sp. Def  Speed  Generation  Legendary  Sum  Average
# 17        25     35           1      False  145     35.0
# 18        80     75           1      False  240     77.5
# 19        80    145           1      False  270    107.5
# ...

# %%
newdata= newdata.reset_index(drop=True)
newdata
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0   14                 Kakuna    Bug  Poison  45      25       50       25
# 1   15               Beedrill    Bug  Poison  65      90       40       45
# 2   15  BeedrillMega Beedrill    Bug  Poison  65     150       40       15
# 3   48                Venonat    Bug  Poison  60      55       50       40
# 4   49               Venomoth    Bug  Poison  70      65       60       90
# 5  168                Ariados    Bug  Poison  70      90       70       60
# 6  269                 Dustox    Bug  Poison  60      50       70       50
# 7  545              Scolipede    Bug  Poison  60     100       89       55
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0       25     35           1      False  145     35.0
# 1       80     75           1      False  240     77.5
# 2       80    145           1      False  270    107.5
# 3       55     45           1      False  205     57.5
# ...

# %% [markdown]
# ## Filter data deeper

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Sum  Average
# 2        100     80           1      False  345     81.0
# 3        120     80           1      False  425     90.0
# 50        90     50           1      False  350     77.5
# 77        70     70           1      False  350     92.5
# 652       80     30           5      False  354     99.5

# %%
new_df= new_df.reset_index(drop=True)

new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0      100     80           1      False  345     81.0
# 1      120     80           1      False  425     90.0
# 2       90     50           1      False  350     77.5
# 3       70     70           1      False  350     92.5
# 4       80     30           5      False  354     99.5

# %%
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    3               Venusaur  Grass  Poison   80      82       83      100
# 1    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 2   45              Vileplume  Grass  Poison   75      80       85      110
# 3   71             Victreebel  Grass  Poison   80     105       65      100
# 4  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0      100     80           1      False  345     81.0
# 1      120     80           1      False  425     90.0
# 2       90     50           1      False  350     77.5
# 3       70     70           1      False  350     92.5
# 4       80     30           5      False  354     99.5

# %%
new_df.to_csv('filtered.csv')

# %% [markdown]
# ## Filter for a value in string

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire             78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# 141  130      GyaradosMega Gyarados     Water      Dark   95     155      109
# 154  142  AerodactylMega Aerodactyl      Rock    Flying   80     135       85
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ...

# %%
df.loc[(df['Name'].str.contains('mega|hoopa'))]
# Out:
#        #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 520  469  Yanmega    Bug  Flying  86      76       86      116       56
#
#      Speed  Generation  Legendary  Sum  Average
# 520     95           4      False  364     81.0

# %%
import re
df.loc[df['Name'].str.contains('Mega'|'Hoopa', regex=True)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1z/cg3wnq050fn_7dl4rd8bccpw0000gn/T/ipykernel_5112/4216732872.py in <module>
#       1 import re
# ----> 2 df.loc[df['Name'].str.contains('Mega'|'Hoopa', regex=True)]
#
# NameError: name 'df' is not defined

# %%
import re

# %%
df.loc[df['Name'].str.contains('mega|hoopa',flags=re.I, regex=True)]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re
df.loc[~df['Name'].str.contains('mega | hoopa', regex=True)]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum  Average
# ...

# %%
df.loc[df['Name'].str.contains('^bu[a-z]*',flags=re.I, regex=True)]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 451  406       Budew  Grass  Poison  40      30       35       50       70
#
#      Speed Generation Legendary  Sum  Average
# 0       45     Test 1    Test 2  208     47.0
# 15      70     Test 1    Test 2  245     52.5
# 451     55     Test 1    Test 2  155     35.0

# %%
df.loc[df['Name'].str.contains('^bu[a-z]*',flags=re.I, regex=True)]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 451  406       Budew  Grass  Poison  40      30       35       50       70
#
#      Speed Generation Legendary  Sum  Average
# 0       45     Test 1    Test 2  208     47.0
# 15      70     Test 1    Test 2  245     52.5
# 451     55     Test 1    Test 2  155     35.0

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Type 1'] =='Bug','Type 1'] = 'Grass'

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum  Average
# ...

# %%
df.loc[df['Type 1'] =='Bug','Type 1'] = 'Grass'
 
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum  Average
# ...

# %%
df = pd.read_csv("sum_ave_pd.csv")
df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
#  12  Sum         800 non-null    int64
#  13  Average     800 non-null    float64
# dtypes: bool(1), float64(1), int64(9), object(3)
# memory usage: 82.2+ KB

# %%
df.loc[df['Type 2']=="Dragon",'Type 2']= " "
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum  Average
# ...

# %%
df.loc[df['Sum'] > 400, ['Generation','Legendary']] = ["new", 'test']

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Sum  Average
# ...

# %%
df = pd.read_csv("sum_ave_pd.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1z/cg3wnq050fn_7dl4rd8bccpw0000gn/T/ipykernel_2596/833909818.py in <module>
# ----> 1 df = pd.read_csv("sum_ave_pd.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0       65     45           1      False  208     47.0
# 1       80     60           1      False  265     61.0
# 2      100     80           1      False  345     81.0
# 3      120     80           1      False  425     90.0
# 4       50     65           1      False  194     45.5

# %% [markdown]
# ## Aggressive Statistics (Group By)

# %%
 df.groupby(['Type 2']).sum()["HP"].sort_values(ascending=False)
# Out:
# Type 2
# Flying      6925
# Ground      2703
# Psychic     2383
# Fighting    2066
# Poison      1998
# Grass       1566
# Dark        1511
# Dragon      1479
# Fairy       1479
# Steel       1422
# Ice         1260
# Rock         953
# Water        878
# Fire         855
# Ghost        828
# Electric     529
# Normal       254
# Bug          160
# Name: HP, dtype: int64

# %%
df.groupby(['Type 1']).sum().sort_values('HP',ascending = False)
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    Sum  \
# Type 1
# Water     33946  8071    8305     8170     8379     7898   7388  32925
# Normal    31279  7573    7200     5865     5470     6245   7012  26108
# Grass     24141  4709    5125     4956     5425     4930   4335  20215
# Psychic   21706  4026    4073     3858     5609     4918   4645  17566
# Bug       23080  3925    4897     4880     3717     4471   4256  17419
# Fire      17025  3635    4408     3524     4627     3755   3871  16194
# Rock      17280  2876    4086     4435     2787     3321   2460  14184
# Dragon    15180  2666    3588     2764     3099     2843   2657  12117
# Electric  15994  2631    3040     2917     3961     3243   3718  12549
# Ground    11401  2361    3064     2715     1807     2008   2045   9947
# Dark      14302  2071    2740     2177     2314     2155   2361   9302
# Ghost     15568  2062    2361     2598     2539     2447   2059   9560
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense',ascending =False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df.groupby(['Type 1']).count().sort_values('Defense',ascending =False)
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     112   112      53  112     112      112      112      112    112
# Normal     98    98      37   98      98       98       98       98     98
# Grass      70    70      37   70      70       70       70       70     70
# Bug        69    69      52   69      69       69       69       69     69
# Psychic    57    57      19   57      57       57       57       57     57
# Fire       52    52      24   52      52       52       52       52     52
# Electric   44    44      17   44      44       44       44       44     44
# Rock       44    44      35   44      44       44       44       44     44
# Ghost      32    32      22   32      32       32       32       32     32
# Ground     32    32      19   32      32       32       32       32     32
# Dragon     32    32      21   32      32       32       32       32     32
# ...

# %%
df.loc[(df["Type 1"]=="Bug")]
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie    Bug     NaN  45      30       35       20       20
# 14    11     Metapod    Bug     NaN  50      20       55       25       25
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 16    13      Weedle    Bug  Poison  40      35       30       20       20
# 17    14      Kakuna    Bug  Poison  45      25       50       25       25
# ..   ...         ...    ...     ...  ..     ...      ...      ...      ...
# 698  637   Volcarona    Bug    Fire  85      60       65      135      105
# 717  649    Genesect    Bug   Steel  71     120       95      120       95
# 732  664  Scatterbug    Bug     NaN  38      35       40       27       25
# 733  665      Spewpa    Bug     NaN  45      22       60       27       30
# 734  666    Vivillon    Bug  Flying  80      52       50       90       50
#
#      Speed  Generation  Legendary  Sum  Average
# ...

# %%
df.groupby(['Type 1']).count()['#'].sort_values(ascending = False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: #, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['#']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: #, Length: 136, dtype: int64

# %%
df.groupby(['Type 1']).sum()['HP']
# Out:
# Type 1
# Bug         3925
# Dark        2071
# Dragon      2666
# Electric    2631
# Fairy       1260
# Fighting    1886
# Fire        3635
# Flying       283
# Ghost       2062
# Grass       4709
# Ground      2361
# Ice         1728
# Normal      7573
# Poison      1883
# Psychic     4026
# Rock        2876
# Steel       1761
# Water       8071
# Name: HP, dtype: int64

# %%
type1_2 = df.groupby(['Type 1','Type 2']).sum()['HP']
# Out:
# Type 1  Type 2
# Bug     Electric    120
#         Fighting    160
#         Fire        140
#         Flying      882
#         Ghost         1
#                    ...
# Water   Ice         270
#         Poison      185
#         Psychic     435
#         Rock        283
#         Steel        84
# Name: HP, Length: 136, dtype: int64

# %% [markdown]
# ## Drop NaN

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head(100))
# Out:
#        #        Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander      Fire    NaN  39      52       43       60       50
# 5      5  Charmeleon      Fire    NaN  58      64       58       80       65
# 9      7    Squirtle     Water    NaN  44      48       65       50       64
# 10     8   Wartortle     Water    NaN  59      63       80       65       80
# 11     9   Blastoise     Water    NaN  79      83      100       85      105
# ..   ...         ...       ...    ...  ..     ...      ...      ...      ...
# 173  159    Croconaw     Water    NaN  65      80       80       59       63
# 174  160  Feraligatr     Water    NaN  85     105      100       79       83
# 175  161     Sentret    Normal    NaN  35      46       34       35       45
# 176  162      Furret    Normal    NaN  85      76       64       45       55
# 186  172       Pichu  Electric    NaN  20      40       15       35       35
#
# ...

# %%
df = df.dropna()
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary  Sum  Average
# 0       65     45           1      False  208     47.0
# 1       80     60           1      False  265     61.0
# 2      100     80           1      False  345     81.0
# 3      120     80           1      False  425     90.0
# 6       85    100           1      False  349     81.0

# %% [markdown]
# ## Which type1 has most HP and least attack ?

# %%
df.groupby(['Type 1']).sum()['HP'].sort_values(ascending= False)
# Out:
# Type 1
# Water       8071
# Normal      7573
# Grass       4709
# Psychic     4026
# Bug         3925
# Fire        3635
# Rock        2876
# Dragon      2666
# Electric    2631
# Ground      2361
# Dark        2071
# Ghost       2062
# Fighting    1886
# Poison      1883
# Steel       1761
# Ice         1728
# Fairy       1260
# Flying       283
# Name: HP, dtype: int64

# %%
df.groupby(['Type 1']).sum()['Attack'].sort_values()
# Out:
# Type 1
# Flying       315
# Fairy       1046
# Ice         1746
# Poison      2091
# Ghost       2361
# Steel       2503
# Fighting    2613
# Dark        2740
# Electric    3040
# Ground      3064
# Dragon      3588
# Psychic     4073
# Rock        4086
# Fire        4408
# Bug         4897
# Grass       5125
# Normal      7200
# Water       8305
# Name: Attack, dtype: int64

# %%
# Visualise the above

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
total_hp = df.groupby(['Type 1']).sum()['HP'].sort_values(ascending= False)
plt.plot(total_hp,)

# %%
total_attack= df.groupby(['Type 1']).sum()['Attack'].sort_values()
plt.plot(total_attack)

# %%
total_hp = df.groupby(['Type 1']).sum()['HP'].sort_values()

key = [a for a, df in df.groupby(['Type 1'])]

# %%
plt.bar(key,total_hp)
# Out:
# <BarContainer object of 18 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_csv("pokemon_data.csv")

total_hp = df.groupby(['Type 1']).sum()['HP'].sort_values(ascending = False)

total_attack = df.groupby(['Type 1']).sum()['Attack'].sort_values()

key = [type for type, df in df.groupby(['Type 1'])]

fig, ax1 = plt.subplots()

#plt.plot(key,total_attack)

ax2 = ax1.twinx()

ax1.bar(key, total_hp, color='g')
ax2.plot(key, total_attack, color='r')

ax1.set_xlabel('Type1')
ax1.set_ylabel('Total HP', color='g')
ax2.set_ylabel('Total Attack', color='r')
ax1.set_xticklabels(key, rotation='vertical', size=8)
# Out:
# /var/folders/1z/cg3wnq050fn_7dl4rd8bccpw0000gn/T/ipykernel_15048/1265689328.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(key, rotation='vertical', size=8)
# [Text(0, 0, 'Bug'),
#  Text(1, 0, 'Dark'),
#  Text(2, 0, 'Dragon'),
#  Text(3, 0, 'Electric'),
#  Text(4, 0, 'Fairy'),
#  Text(5, 0, 'Fighting'),
#  Text(6, 0, 'Fire'),
#  Text(7, 0, 'Flying'),
#  Text(8, 0, 'Ghost'),
#  Text(9, 0, 'Grass'),
#  Text(10, 0, 'Ground'),
#  Text(11, 0, 'Ice'),
#  Text(12, 0, 'Normal'),
#  Text(13, 0, 'Poison'),
#  Text(14, 0, 'Psychic'),
#  Text(15, 0, 'Rock'),
#  Text(16, 0, 'Steel'),
#  Text(17, 0, 'Water')]

# %% [markdown]
# ## Assessment 1: Tax Data Analysis using Pandas

# %% [markdown]
# ### Univariate Analysis

# %%
# Out:
# (414, 14)
